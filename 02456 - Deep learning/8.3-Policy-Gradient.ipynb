# %% [markdown]
# # Solve cartpole with REINFORCE
#
# > By Jonas Busk ([jbusk@dtu.dk](mailto:jbusk@dtu.dk))
#
# **2019 update:** Changes have been made to the display of environments due to the previous `viewer` being incompatible with newer versions of Gym.
#
# In this part, we will create an agent that can learn to solve the [cartpole problem](https://gym.openai.com/envs/CartPole-v0/) from OpenAI Gym by applying a simple policy gradient method called REINFORCE.
# In the cartpole problem, we need to balance a pole on a cart that moves along a track by applying left and right forces to the cart.
#
# We will implement a probabilistic policy, that given a state of the environment, $s$, outputs a probability distribution over available actions, $a$:
#
# $$
# p_\theta(a|s)
# $$
#
# The policy is a neural network with parameters $\theta$ that can be trained with gradient descent.
# When the set of available actions is discrete, we can use a network with softmax output do describe the distribution.
# The core idea of training the policy network is quite simple: *we want to maximize the expected total reward by increasing the probability of good actions and decreasing the probability of bad actions*.
#
# To achieve this, we apply the gradient of the expected discounted total reward (return):
#
# $$
# \begin{align}
# \nabla_\theta \mathbb{E}[R|\theta] &= \nabla_\theta \int p_\theta(a|s) R({a}) \, da \\
# &= \int \nabla_\theta p_\theta(a|s) R(a)  \, da \\
# &= \int p_\theta(a|s) \nabla_\theta \log p_\theta(a|s) R(a) \, da \\
# &= \mathbb{E}[\nabla_\theta \log p_\theta(a|s) R(a)]
# \end{align}
# $$
#
# by definition of expectation and using the identity
#
# $$
# \nabla_\theta p_\theta(a|s) = p_\theta(a|s) \nabla_\theta \log p_\theta(a|s) \ .
# $$
#
# The expectation cannot be evaluated analytically, but we have an environment simulator that when supplied with our current policy $p_\theta(a|s)$ can return a sequence of *actions*, *states* and *rewards*. This allows us to replace the integral with a Monte Carlo average:
#
# $$
# \nabla_\theta \mathbb{E}[R|\theta] \approx \frac{1}{T} \sum_{t=0}^T \nabla_\theta \log p_\theta(a_t|s_t) R_t \ ,
# $$
#
# which is our final gradient estimator, also known as REINFORCE. In the Monte Carlo estimator we run the environment simulator for a predefined number of steps with actions chosen stochastically according to the current stochastic action network $p_\theta(a|s)$.

# %% [markdown]
# *Note: For simple reinforcement learning problems (like the one we will address in this exercise) there are simpler methods that work just fine. However, the Policy Gradient method (with some extensions) has been shown to also work well for complex problems with high dimensional inputs and many parameters, where simple methods become inadequate.*

# %%
#!pip install -U 'mujoco-py<2.1,>=2.0'

#!pip install gym[all]

#!python -h

# %% [markdown]
# ## Policy gradient

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import gym
from gym import wrappers

# %% [markdown]
# First we create the environment:

# %%
env = gym.make('CartPole-v0') # Create environment

# %% [markdown]
# A state in this environment is four numbers describing the position of the cart along with the angle and speed of the pole.
# There are two available actions: push the cart *left* or *right* encoded as 0 and 1.

# %%
s = env.reset()
a = env.action_space.sample()
print('sample state:', s)
print('sample action:', a )
# Out:
# sample state: [-0.03904621 -0.03878013  0.02920226 -0.00368749]
# sample action: 1

# %% [markdown]
# **Note:** you will likely not be able to render environments in a Google Colab instance. Therefore, it may be beneficial for you to run this week's notebooks locally and/or team up with another student if you do not have a local environment.
#
# The function below is used for display:

# %%
def show_replay():
    """
    Not-so-elegant way to display the MP4 file generated by the Monitor wrapper inside a notebook.
    The Monitor wrapper dumps the replay to a local file that we then display as a HTML video object.
    """
    import io
    import base64
    from IPython.display import HTML
    video = io.open('./gym-results/openaigym.video.%s.video000000.mp4' % env.file_infix, 'r+b').read()
    encoded = base64.b64encode(video)
    return HTML(data='''
        <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,{0}" type="video/mp4" /></video>'''
    .format(encoded.decode('ascii')))

# %% [markdown]
# Let us see how the environment looks when we just take random actions. Note that the episode ends when the pole either 1) is more than 15 degrees from vertical, 2) more outside of the frame or 3) the pole is successfully balanced for some fixed duration.

# %%
env = gym.make('CartPole-v0') # Create environment
env = wrappers.Monitor(env, "./gym-results", force=True) # Create wrapper to display environment
env.reset() # Reset environment

# Run environment
while True:
    env.render() # Render environment
    action = env.action_space.sample() # Get a random action
    _, _, done, _ = env.step(action) # Take a step
    if done: break # Break if environment is done

env.close() # Close environment
show_replay()
# Out:
# 2021-10-25 15:14:08.759 python[39882:3145155] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fd640de01c0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2021-10-25 15:14:08.760 python[39882:3145155] Warning: Expected min height of view: (<NSButton: 0x7fd6441254a0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2021-10-25 15:14:08.763 python[39882:3145155] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fd644128db0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2021-10-25 15:14:08.765 python[39882:3145155] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fd644b11200>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>

# %% [markdown]
# Taking random actions does not do a very good job at balancing the pole. Let us now apply the Policy Gradient method described above to solve this task!
#
# Let's first define our network and helper functions.

# %%
class PolicyNet(nn.Module):
    """Policy network"""

    def __init__(self, n_inputs, n_hidden, n_outputs, learning_rate):
        super(PolicyNet, self).__init__()
        # network
        self.hidden = nn.Linear(n_inputs, n_hidden)
        self.hidden2 = nn.Linear(n_hidden, n_hidden)
        self.hidden3 = nn.Linear(n_hidden, 10)
        self.out = nn.Linear(10, n_outputs)
        # training
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, x):
        x = self.hidden(x)
        x = F.relu(x)
        x = self.hidden2(x)
        x = F.tanh(x)
        x = self.hidden3(x)
        x = F.relu(x)
        x = self.out(x)
        return F.softmax(x, dim=1)
    
    def loss(self, action_probabilities, returns):
        return -torch.mean(torch.mul(torch.log(action_probabilities), returns))

# %%
def compute_returns(rewards, discount_factor):
    """Compute discounted returns."""
    returns = np.zeros(len(rewards))
    returns[-1] = rewards[-1]
    for t in reversed(range(len(rewards)-1)):
        returns[t] = rewards[t] + discount_factor * returns[t+1]
    return returns

# %% [markdown]
# To start with, our policy will be a rather simple neural network with one hidden layer. We can retrieve the shape of the state space (input) and action space (output) from the environment.

# %%
n_inputs = env.observation_space.shape[0]
n_hidden = 20
n_outputs = env.action_space.n

print('state shape:', n_inputs)
print('action shape:', n_outputs)
# Out:
# state shape: 4
# action shape: 2

# %%
# training settings

num_episodes = 10000
rollout_limit = 500 # max rollout length
discount_factor = 0.95 # reward discount factor (gamma), 1.0 = no discount
learning_rate = 0.001 # you know this by now
val_freq = 10 # validation frequency

# setup policy network

policy = PolicyNet(n_inputs, n_hidden, n_outputs, learning_rate)

# train policy network
try:
    training_rewards, losses = [], []
    print('start training')
    for i in range(num_episodes):
        rollout = []
        s = env.reset()
        for j in range(rollout_limit):
            # generate rollout by iteratively evaluating the current policy on the environment
            with torch.no_grad():
                a_prob = policy(torch.from_numpy(np.atleast_2d(s)).float())
                a = torch.multinomial(a_prob, num_samples=1).squeeze().numpy()
            s1, r, done, _ = env.step(a)
            rollout.append((s, a, r))
            s = s1
            if done: break
        # prepare batch
        rollout = np.array(rollout)
        states = np.vstack(rollout[:,0])
        actions = np.vstack(rollout[:,1])
        rewards = np.array(rollout[:,2], dtype=float)
        returns = compute_returns(rewards, discount_factor)
        # policy gradient update
        policy.optimizer.zero_grad()
        a_probs = policy(torch.from_numpy(states).float()).gather(1, torch.from_numpy(actions)).view(-1)
        loss = policy.loss(a_probs, torch.from_numpy(returns).float())
        loss.backward()
        policy.optimizer.step()
        # bookkeeping
        training_rewards.append(sum(rewards))
        losses.append(loss.item())
        # print
        if (i+1) % val_freq == 0:
            # validation
            validation_rewards = []
            for _ in range(10):
                s = env.reset()
                reward = 0
                for _ in range(rollout_limit):
                    with torch.no_grad():
                        a_prob = policy(torch.from_numpy(np.atleast_2d(s)).float())
                        a = a_prob.argmax().item()
                    s, r, done, _ = env.step(a)
                    reward += r
                    if done: break
                validation_rewards.append(reward)
            if (i+1) % (100) == 0:
                print('{:4d}. mean training reward: {:6.2f}, mean validation reward: {:6.2f}, mean loss: {:7.4f}'.format(i+1, np.mean(training_rewards[-val_freq:]), np.mean(validation_rewards), np.mean(losses[-val_freq:])))
    print('done')
except KeyboardInterrupt:
    print('interrupt')
# Out:
# start training
# /var/folders/f_/09zgsjw54xvfw3k8907hvrnw0000gn/T/ipykernel_39882/3998394908.py:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   rollout = np.array(rollout)
#  100. mean training reward:  13.80, mean validation reward:   9.30, mean loss:  3.5922
#  200. mean training reward:  14.00, mean validation reward:   9.00, mean loss:  3.9401
#  300. mean training reward:  17.00, mean validation reward:   9.30, mean loss:  4.4531
#  400. mean training reward:  13.60, mean validation reward:   9.50, mean loss:  3.5059
#  500. mean training reward:  13.80, mean validation reward:   9.40, mean loss:  3.4227
#  600. mean training reward:  14.10, mean validation reward:   9.30, mean loss:  3.5843
#  700. mean training reward:  16.30, mean validation reward:   9.30, mean loss:  4.0671
#  800. mean training reward:  21.60, mean validation reward:  15.70, mean loss:  5.1046
#  900. mean training reward:  66.70, mean validation reward:  92.90, mean loss:  8.3867
# 1000. mean training reward:  32.40, mean validation reward:  44.90, mean loss:  6.2112
# 1100. mean training reward:  24.90, mean validation reward:  27.20, mean loss:  5.1264
# 1200. mean training reward:  34.00, mean validation reward:  33.20, mean loss:  5.9233
# 1300. mean training reward:  42.60, mean validation reward:  46.10, mean loss:  6.6235
# 1400. mean training reward:  41.70, mean validation reward:  43.60, mean loss:  6.6787
# 1500. mean training reward:  40.20, mean validation reward:  52.80, mean loss:  6.3129
# 1600. mean training reward:  44.40, mean validation reward:  48.30, mean loss:  7.0822
# 1700. mean training reward:  38.00, mean validation reward:  44.80, mean loss:  6.1940
# 1800. mean training reward:  23.20, mean validation reward:  23.70, mean loss:  4.5478
# 1900. mean training reward:  30.20, mean validation reward:  39.40, mean loss:  5.3282
# 2000. mean training reward:  62.00, mean validation reward:  83.10, mean loss:  7.1917
# 2100. mean training reward: 107.50, mean validation reward: 125.10, mean loss:  8.7207
# 2200. mean training reward: 120.40, mean validation reward: 136.60, mean loss:  9.1600
# 2300. mean training reward: 134.50, mean validation reward: 154.20, mean loss:  9.1041
# 2400. mean training reward: 166.00, mean validation reward: 170.50, mean loss:  9.6423
# 2500. mean training reward:  40.60, mean validation reward:  99.20, mean loss:  5.7971
# 2600. mean training reward: 132.60, mean validation reward: 142.30, mean loss:  8.8974
# 2700. mean training reward:  47.30, mean validation reward: 103.10, mean loss:  5.8973
# 2800. mean training reward:  35.00, mean validation reward:  97.90, mean loss:  4.8573
# 2900. mean training reward:  53.20, mean validation reward:  95.80, mean loss:  5.7848
# 3000. mean training reward: 136.70, mean validation reward: 137.50, mean loss:  8.3384
# 3100. mean training reward:  56.90, mean validation reward:  97.30, mean loss:  5.7961
# 3200. mean training reward: 117.00, mean validation reward: 124.00, mean loss:  8.1468
# 3300. mean training reward: 127.90, mean validation reward: 134.90, mean loss:  8.4284
# 3400. mean training reward: 168.40, mean validation reward: 191.70, mean loss:  8.6613
# 3500. mean training reward: 199.60, mean validation reward: 200.00, mean loss:  8.6415
# 3600. mean training reward: 200.00, mean validation reward: 200.00, mean loss:  8.8651
# 3700. mean training reward: 200.00, mean validation reward: 200.00, mean loss:  8.5236
# 3800. mean training reward: 200.00, mean validation reward: 200.00, mean loss:  8.5079
# 3900. mean training reward: 200.00, mean validation reward: 200.00, mean loss:  8.4516
# 4000. mean training reward: 200.00, mean validation reward: 200.00, mean loss:  8.4221
# 4100. mean training reward: 200.00, mean validation reward: 200.00, mean loss:  8.4651
# 4200. mean training reward: 200.00, mean validation reward: 200.00, mean loss:  8.0994
# 4300. mean training reward: 198.30, mean validation reward: 200.00, mean loss:  8.3112
# 4400. mean training reward: 126.10, mean validation reward: 124.10, mean loss:  7.2773
# 4500. mean training reward: 179.80, mean validation reward: 194.80, mean loss:  7.8079
# 4600. mean training reward: 167.10, mean validation reward: 175.50, mean loss:  7.1431
# 4700. mean training reward: 125.10, mean validation reward: 126.60, mean loss:  7.6915
# 4800. mean training reward:  89.10, mean validation reward:  96.20, mean loss:  6.6574
# 4900. mean training reward: 121.20, mean validation reward: 126.60, mean loss:  7.3291
# 5000. mean training reward: 172.70, mean validation reward: 184.90, mean loss:  7.6189
# 5100. mean training reward: 100.60, mean validation reward: 103.60, mean loss:  7.1376
# 5200. mean training reward:  35.30, mean validation reward:  82.80, mean loss:  4.7097
# 5300. mean training reward:  87.30, mean validation reward: 104.80, mean loss:  6.4812
# 5400. mean training reward: 128.80, mean validation reward: 144.10, mean loss:  7.9813
# 5500. mean training reward:  68.80, mean validation reward: 104.80, mean loss:  6.4404
# 5600. mean training reward:  54.60, mean validation reward:  96.90, mean loss:  5.5318
# 5700. mean training reward:  63.60, mean validation reward: 105.60, mean loss:  5.7999
# 5800. mean training reward:  59.50, mean validation reward: 102.20, mean loss:  5.3885
# 5900. mean training reward: 100.40, mean validation reward: 117.80, mean loss:  7.2318
# 6000. mean training reward: 150.80, mean validation reward: 158.00, mean loss:  7.9434
# 6100. mean training reward: 163.10, mean validation reward: 171.30, mean loss:  8.0375
# 6200. mean training reward:  73.50, mean validation reward: 104.40, mean loss:  5.9593
# 6300. mean training reward:  52.50, mean validation reward: 112.40, mean loss:  5.0689
# 6400. mean training reward:  34.40, mean validation reward:  78.70, mean loss:  3.9871
# 6500. mean training reward:  41.50, mean validation reward: 102.30, mean loss:  4.3429
# 6600. mean training reward: 108.00, mean validation reward: 111.60, mean loss:  7.1430
# 6700. mean training reward:  89.40, mean validation reward: 121.50, mean loss:  6.5647
# 6800. mean training reward: 120.20, mean validation reward: 152.90, mean loss:  7.1032
# 6900. mean training reward:  24.40, mean validation reward:  98.70, mean loss:  3.5794
# 7000. mean training reward:  13.40, mean validation reward: 103.50, mean loss:  2.2274
# 7100. mean training reward:  39.10, mean validation reward: 114.60, mean loss:  4.0527
# 7200. mean training reward:  12.50, mean validation reward:  13.80, mean loss:  1.9824
# 7300. mean training reward:  26.10, mean validation reward:  94.70, mean loss:  3.3498
# 7400. mean training reward:  15.10, mean validation reward:  79.60, mean loss:  2.6884
# 7500. mean training reward:  58.90, mean validation reward: 122.40, mean loss:  4.7191
# 7600. mean training reward:  45.90, mean validation reward:  96.00, mean loss:  4.6208
# 7700. mean training reward:  25.20, mean validation reward:  44.80, mean loss:  3.1548
# 7800. mean training reward:  17.40, mean validation reward:  26.30, mean loss:  2.5430
# 7900. mean training reward:  14.40, mean validation reward:  14.30, mean loss:  2.1419
# 8000. mean training reward:  45.30, mean validation reward: 108.60, mean loss:  4.3283
# 8100. mean training reward:  11.20, mean validation reward:  12.00, mean loss:  1.7908
# 8200. mean training reward:  12.10, mean validation reward:  13.00, mean loss:  1.8820
# 8300. mean training reward:  11.50, mean validation reward:  12.00, mean loss:  1.2044
# 8400. mean training reward:  13.00, mean validation reward:  13.60, mean loss:  1.8519
# 8500. mean training reward:  16.50, mean validation reward:  88.20, mean loss:  2.1560
# 8600. mean training reward:  34.10, mean validation reward:  35.10, mean loss:  2.9697
# 8700. mean training reward:  68.30, mean validation reward: 105.70, mean loss:  5.1863
# 8800. mean training reward:  94.80, mean validation reward: 109.70, mean loss:  5.8732
# 8900. mean training reward:  13.80, mean validation reward:  16.80, mean loss:  1.9023
# 9000. mean training reward:  80.20, mean validation reward: 110.40, mean loss:  5.5844
# 9100. mean training reward:  96.00, mean validation reward: 105.50, mean loss:  6.1124
# 9200. mean training reward:  64.90, mean validation reward: 111.50, mean loss:  4.6379
# 9300. mean training reward: 115.90, mean validation reward: 116.50, mean loss:  6.7151
# 9400. mean training reward:  25.60, mean validation reward:  32.90, mean loss:  3.4055
# 9500. mean training reward:  73.90, mean validation reward:  86.00, mean loss:  5.3467
# 9600. mean training reward:  68.90, mean validation reward:  97.70, mean loss:  4.8303
# 9700. mean training reward: 120.00, mean validation reward: 120.90, mean loss:  6.1561
# 9800. mean training reward: 167.30, mean validation reward: 171.20, mean loss:  6.4577
# 9900. mean training reward: 151.70, mean validation reward: 156.60, mean loss:  6.5563
# 10000. mean training reward: 189.50, mean validation reward: 191.60, mean loss:  6.9847
# done

# %%
# plot results
def moving_average(a, n=10) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret / n

plt.figure(figsize=(16,6))
plt.subplot(211)
plt.plot(range(1, len(training_rewards)+1), training_rewards, label='training reward')
plt.plot(moving_average(training_rewards))
plt.xlabel('episode'); plt.ylabel('reward')
plt.xlim((0, len(training_rewards)))
plt.legend(loc=4); plt.grid()
plt.subplot(212)
plt.plot(range(1, len(losses)+1), losses, label='loss')
plt.plot(moving_average(losses))
plt.xlabel('episode'); plt.ylabel('loss')
plt.xlim((0, len(losses)))
plt.legend(loc=4); plt.grid()
plt.tight_layout(); plt.show()

# %% [markdown]
# Now let's review the solution!

# %%
env = wrappers.Monitor(env, "./gym-results", force=True) # Create wrapper to display environment
s = env.reset()

for _ in range(500):
    env.render()
    a = policy(torch.from_numpy(np.atleast_2d(s)).float()).argmax().item()
    s, r, done, _ = env.step(a)
    if done: break
    
env.close()
show_replay()
# Out:
# 2021-10-25 17:29:17.662 python[39882:3145155] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fd627c71610>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2021-10-25 17:29:17.665 python[39882:3145155] Warning: Expected min height of view: (<NSButton: 0x7fd63c855690>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2021-10-25 17:29:17.673 python[39882:3145155] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fd63c857200>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2021-10-25 17:29:17.678 python[39882:3145155] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7fd627c78760>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# /opt/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py:1794: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>

# %% [markdown]
# ## Reducing variance
#
# By default, this gradient estimator has high variance and therefore variance reduction becomes important to learn more complex tasks.
# We can reduce variance by subtracting a baseline from the returns, which is unbiased in expectation:
#
# $$
# \nabla_\theta \mathbb{E}[R|\theta] \approx \frac{1}{T} \sum_{t=0}^T \nabla_\theta \log p_\theta(a_t|s_t) (R_t-b_t) \ ,
# $$
#
# where the baseline, $b_t$, is estimated by the return a timestep $t$ averaged over $V$ rollouts.
#
# $$
# b_t = \frac{1}{V} \sum_{v=1}^V R_t^{(v)} \ .
# $$

# %% [markdown]
# ## Exercises
#
# Now it is your turn! Make sure you read and understand the code, then play around with it and try to make it learn better and faster.
#
# Experiment with the:
#
# * number of episodes
# * discount factor
# * learning rate
# * network layers
#
#
# ### Exercise 1
#
# *Describe any changes you made to the code and why you think they improve the agent. Are you able to get solutions consistently?*
#
# **Answer:**
#
# I played around with all the four mentioned variables. I found that 3 layers works best, a learning rate of 1e-3 and a discount factor in the region of 0.9. Regarding the number of episodes, this is analouge to the epoch used many times before. Therefore it needs to be large enough that the system can find a minima, but small enough that it can train in a reasonable amount of time.
# In general, I found that while there certainly are some network structures/work-rates/discount factors that does not work, the ones that do does no always work either. Becasue one solution was good, does not mean it will be so the next time you run it.
# I actually found that the val_freq is very important for finding a good solution.
#
# ### Exercise 2
#
# *Consider the following sequence of rewards produced by an agent interacting with an environment for 10 timesteps:*
#
# [0, 1, 1, 1, 0, 1, 1, 0, 0, 0]
#
# * *What is the total reward?*
# * *What is the total future reward in each timestep?*
# * *What is the discounted future reward in each timestep if $\gamma = 0.9$?*
#
# *Hint: See introdution notebook.*
#
# **Answer:**
#
# Total reward:
# 5
#
# Total future reward in each timestep:
# [5, 5, 4, 3, 2, 2, 1, 0, 0, 0]
#
# Total discounted future reward ($\gamma = 0.9$):
# [3.6, 4.0, 3.3, 2.5, 1.7, 1.9, 1.0, 0.0, 0.0, 0.0]
#
#
# ### Exercise 3
#
# *In the training output, you will sometimes observe the validation reward starts out lower than the training reward but as training progresses they cross over and the validation reward becomes higher than the training reward. How can you explain this behavior?*
#
# *Hint: Do we use the policy network in the same way during training and validation?*
#
# **Answer:**
# In training we use some randomly selected random variables with given parameters. In validation we use the most probably parameters. In other words, we are adding some noise to the parameters when training to explore. Once the network has gotten a good idea of the parameters we might therefore see that validation reward becomes higher than the training.
#
#
# ### Exercise 4
#
# *How does the policy gradient method we have used address the exploration-exploitation dilemma?*
#
# *Hint: See the introduction notebook about exploration-exploitation.*
#
# **Answer:**
# As just mentioned, it does so by randomly sampling parameters in training with fitting mean values. This ensures that the method tries different combinations "close to" whatever has been the one that worked best so far. How close the parameters are can be controlled in the sampling process, and should become "closer and closer" over time.
#
#
# ### Exercise 5 [optional]
#
# Extend the code above to reduce variance of the gradient estimator by computing and subtracting the baseline estimate.
#
# *Hint: You need to sample a batch of rollouts (now we sample just one) for each update in order to compute the baseline, $b_t$.*
